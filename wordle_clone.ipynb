# %% [markdown]
# # Project Description

# %% [markdown]
# My idea is to try to code an amateur Wordle game. The user inputs guesses to try to solve what the secret word is. The code grades each guess, checking for correct letters, correct positions, and incorrect letters, and returns the feedback.

# %% [markdown]
# ## Project Code

# %%
from my_module.functions import play_wordle_game

# %%
# Run this before play_wordle_game in order to choose Wordle word
import random
import numpy as np

# NOTE: this function was made with the guidance of ChatGPT
# pulls the data from the modified text file found on Github 
with open('my_module/wordle_words/wordle_words_no_repeats.txt', 'r') as file:
    wordle_words = file.read().splitlines()
    
    # chooses random Wordle word from text file
    wordle_word = random.choice(wordle_words)


play_wordle_game(wordle_words, wordle_word)
# Out:
# WORDLE GAME: Guess the mystery word in 6 tries or less!
#
# Guesses must be 5 letters, with no repeating letters.
#
# Key: a . represents a correct letter in the correct position
#      a - represents a correct letter in the incorrect position
#      a / represents an incorrect letter in your guess.
# INPUT :	 audio
# ////-
# INPUT :	 south
# .-///
# INPUT :	 spore
# ././/

# %%
# test it out
# !pytest

# %% [markdown]
# #### Extra Credit (*optional*)
# I came into this class with no Python background at all. I have been exposed to code a few times in my life, but barely understood anything beyond basic algorithmic thinking; I was able to code what I was told to do previously with a lot of help, but never understood what I was doing.
#
# I challenged myself greatly in this project when trying to recreate my own amateur version of the popular Wordle game, and faced significant hurdles. I pushed myself far beyond what was necessary and what I thought I could do by not just developing functions to grade a Wordle guess, which was difficult enough for me in itself, but also creating further functions in order to fully operationalize a Wordle game, which integrated concepts from chatbots and involved me finding ways for the game to be fully self-running. I had to overcome a large amount of issues with this project, from trying to code concepts that were far beyond my knowledge to debugging my code for long periods of time to figuring out how to set it all up and running. I even went out of my way to find a Github file with a list of Wordle words in order to not hard code a Wordle word, and ran into issues there (it had repeats and I coded for words with no repeats) and ended up making an additional function to modify the file to be what I needed. This project was SO many levels beyond what I thought I could achieve, and it took an immense aount of work that I am proud of. It's not perfect by any means, but being such a beginner to programming I feel very accomplished with the results of my project.
